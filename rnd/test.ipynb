# %%
import pandas as pd
from confluent_kafka import Producer
import numpy as np
import json

# Konfigurasi Kafka
KAFKA_BROKER = "localhost:9093"
producer_conf = {"bootstrap.servers": KAFKA_BROKER}
producer = Producer(producer_conf)

# Fungsi untuk membaca file daftar topic dan CSV
def read_topic_csv_mapping(file_txt):
    try:
        with open(file_txt, "r") as f:
            lines = f.readlines()
        mappings = [line.strip().split(",") for line in lines if line.strip()]
        return mappings
    except Exception as e:
        print(f"❌ Gagal membaca file '{file_txt}': {e}")
        return []

# Fungsi membaca CSV
def read_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except Exception as e:
        print(f"❌ Gagal membaca CSV '{file_path}': {e}")
        return None

# Buat schema dinamis berdasarkan CSV
def generate_schema(df):
    schema_fields = []
    for column in df.columns:
        if pd.api.types.is_integer_dtype(df[column]):
            field_type = "int32"
        elif pd.api.types.is_float_dtype(df[column]):
            field_type = "float"
        elif pd.api.types.is_bool_dtype(df[column]):
            field_type = "boolean"
        else:
            field_type = "string"
        schema_fields.append({
            "type": field_type,
            "optional": True,
            "field": column
        })
    return {
        "schema": {
            "type": "struct",
            "fields": schema_fields,
            "optional": False,
            "name": "dynamic_schema"
        }
    }

# Konversi NaN ke `null`
def replace_nan(obj):
    return None if (isinstance(obj, float) and np.isnan(obj)) else obj

# Callback Kafka
def delivery_report(err, msg):
    if err is not None:
        print(f"❌ Gagal mengirim pesan: {err}")
    else:
        print(f"✅ Data dikirim ke Kafka: {msg.topic()} [{msg.partition()}] dengan key: {msg.key().decode('utf-8')}")

# Fungsi untuk mengirim data ke Kafka
def send_to_kafka(topic_name, file_path):
    df = read_csv(file_path)
    if df is None or df.empty:
        print(f"❌ Tidak ada data dalam file '{file_path}'.")
        return

    schema_template = generate_schema(df)  # Buat schema berdasarkan CSV
    total_sent = 0  # Counter untuk tracking jumlah row yang berhasil dikirim

    for _, row in df.iterrows():
        row_dict = {col: replace_nan(row[col]) for col in df.columns}
        key = str(row_dict.get("id", "unknown"))  # Ambil ID sebagai key utama
        message = schema_template.copy()
        message["payload"] = row_dict

        try:
            producer.produce(
                topic_name,
                key=key.encode("utf-8"),
                value=json.dumps(message, ensure_ascii=False).encode("utf-8"),
                callback=delivery_report
            )
            total_sent += 1
        except Exception as e:
            print(f"❌ Gagal mengirim row {key}: {e}")

    producer.flush()  # Pastikan semua pesan benar-benar dikirim sebelum selesai
    print(f"✅ {total_sent}/{len(df)} data berhasil dikirim ke Kafka di topic '{topic_name}'!")

# Jalankan program dengan looping
file_txt = "list_file.txt"  # Ganti dengan path file daftar topic dan CSV
mappings = read_topic_csv_mapping(file_txt)

for topic, csv_file in mappings:
    print(f"🔄 Memproses: Topic='{topic}', File='{csv_file}'")
    send_to_kafka(topic, csv_file)
# Out:
# 🔄 Memproses: Topic='table.public.tbl_branch', File='df_branch.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 5
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 6
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 7
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 8
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 9
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 10
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 11
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 12
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 13
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 14
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 15
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 16
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 17
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 18
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 19
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 20
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 21
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 22
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 23
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 24
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 25
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 26
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 27
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 28
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 29
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 30
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 31
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 32
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 33
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 34
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 35
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 36
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 37
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 38
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 39
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 40
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 41
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 42
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 43
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 44
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 45
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 46
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 47
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 48
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 49
# ✅ Data dikirim ke Kafka: table.public.tbl_branch [0] dengan key: 50
# ✅ 50/50 data berhasil dikirim ke Kafka di topic 'table.public.tbl_branch'!
# 🔄 Memproses: Topic='table.public.tbl_customers', File='df_cust.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 5
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 6
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 7
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 8
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 9
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 10
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 11
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 12
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 13
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 14
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 15
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 16
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 17
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 18
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 19
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 20
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 21
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 22
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 23
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 24
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 25
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 26
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 27
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 28
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 29
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 30
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 31
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 32
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 33
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 34
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 35
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 36
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 37
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 38
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 39
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 40
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 41
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 42
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 43
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 44
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 45
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 46
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 47
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 48
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 49
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 50
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 51
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 52
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 53
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 54
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 55
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 56
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 57
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 58
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 59
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 60
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 61
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 62
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 63
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 64
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 65
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 66
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 67
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 68
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 69
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 70
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 71
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 72
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 73
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 74
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 75
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 76
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 77
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 78
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 79
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 80
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 81
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 82
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 83
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 84
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 85
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 86
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 87
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 88
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 89
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 90
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 91
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 92
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 93
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 94
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 95
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 96
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 97
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 98
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 99
# ✅ Data dikirim ke Kafka: table.public.tbl_customers [0] dengan key: 100
# ✅ 100/100 data berhasil dikirim ke Kafka di topic 'table.public.tbl_customers'!
# 🔄 Memproses: Topic='table.public.tbl_employee', File='df_employee.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 5
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 6
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 7
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 8
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 9
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 10
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 11
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 12
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 13
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 14
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 15
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 16
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 17
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 18
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 19
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 20
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 21
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 22
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 23
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 24
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 25
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 26
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 27
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 28
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 29
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 30
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 31
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 32
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 33
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 34
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 35
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 36
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 37
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 38
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 39
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 40
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 41
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 42
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 43
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 44
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 45
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 46
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 47
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 48
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 49
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 50
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 51
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 52
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 53
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 54
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 55
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 56
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 57
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 58
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 59
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 60
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 61
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 62
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 63
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 64
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 65
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 66
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 67
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 68
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 69
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 70
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 71
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 72
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 73
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 74
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 75
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 76
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 77
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 78
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 79
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 80
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 81
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 82
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 83
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 84
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 85
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 86
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 87
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 88
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 89
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 90
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 91
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 92
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 93
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 94
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 95
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 96
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 97
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 98
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 99
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 100
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 101
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 102
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 103
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 104
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 105
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 106
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 107
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 108
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 109
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 110
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 111
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 112
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 113
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 114
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 115
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 116
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 117
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 118
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 119
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 120
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 121
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 122
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 123
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 124
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 125
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 126
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 127
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 128
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 129
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 130
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 131
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 132
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 133
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 134
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 135
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 136
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 137
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 138
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 139
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 140
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 141
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 142
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 143
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 144
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 145
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 146
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 147
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 148
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 149
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 150
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 151
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 152
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 153
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 154
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 155
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 156
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 157
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 158
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 159
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 160
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 161
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 162
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 163
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 164
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 165
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 166
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 167
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 168
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 169
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 170
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 171
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 172
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 173
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 174
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 175
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 176
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 177
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 178
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 179
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 180
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 181
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 182
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 183
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 184
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 185
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 186
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 187
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 188
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 189
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 190
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 191
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 192
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 193
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 194
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 195
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 196
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 197
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 198
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 199
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 200
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 201
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 202
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 203
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 204
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 205
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 206
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 207
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 208
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 209
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 210
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 211
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 212
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 213
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 214
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 215
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 216
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 217
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 218
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 219
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 220
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 221
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 222
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 223
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 224
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 225
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 226
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 227
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 228
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 229
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 230
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 231
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 232
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 233
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 234
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 235
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 236
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 237
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 238
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 239
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 240
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 241
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 242
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 243
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 244
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 245
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 246
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 247
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 248
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 249
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 250
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 251
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 252
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 253
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 254
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 255
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 256
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 257
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 258
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 259
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 260
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 261
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 262
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 263
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 264
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 265
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 266
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 267
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 268
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 269
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 270
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 271
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 272
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 273
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 274
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 275
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 276
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 277
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 278
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 279
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 280
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 281
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 282
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 283
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 284
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 285
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 286
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 287
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 288
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 289
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 290
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 291
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 292
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 293
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 294
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 295
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 296
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 297
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 298
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 299
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 300
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 301
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 302
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 303
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 304
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 305
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 306
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 307
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 308
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 309
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 310
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 311
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 312
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 313
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 314
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 315
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 316
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 317
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 318
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 319
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 320
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 321
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 322
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 323
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 324
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 325
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 326
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 327
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 328
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 329
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 330
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 331
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 332
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 333
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 334
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 335
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 336
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 337
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 338
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 339
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 340
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 341
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 342
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 343
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 344
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 345
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 346
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 347
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 348
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 349
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 350
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 351
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 352
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 353
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 354
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 355
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 356
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 357
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 358
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 359
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 360
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 361
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 362
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 363
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 364
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 365
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 366
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 367
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 368
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 369
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 370
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 371
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 372
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 373
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 374
# ✅ Data dikirim ke Kafka: table.public.tbl_employee [0] dengan key: 375
# ✅ 375/375 data berhasil dikirim ke Kafka di topic 'table.public.tbl_employee'!
# 🔄 Memproses: Topic='table.public.tbl_order_status', File='df_order_status.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_order_status [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_order_status [0] dengan key: 1
# ✅ 2/2 data berhasil dikirim ke Kafka di topic 'table.public.tbl_order_status'!
# 🔄 Memproses: Topic='table.public.tbl_payment_method', File='df_payment_method.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_method [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_method [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_method [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_method [0] dengan key: 3
# ✅ 4/4 data berhasil dikirim ke Kafka di topic 'table.public.tbl_payment_method'!
# 🔄 Memproses: Topic='table.public.tbl_product', File='df_product.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 5
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 6
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 7
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 8
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 9
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 10
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 11
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 12
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 13
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 14
# ✅ Data dikirim ke Kafka: table.public.tbl_product [0] dengan key: 15
# ✅ 15/15 data berhasil dikirim ke Kafka di topic 'table.public.tbl_product'!
# 🔄 Memproses: Topic='table.public.tbl_promotions', File='df_promotions.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 5
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 6
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 7
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 8
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 9
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 10
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 11
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 12
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 13
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 14
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 15
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 16
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 17
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 18
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 19
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 20
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 21
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 22
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 23
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 24
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 25
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 26
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 27
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 28
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 29
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 30
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 31
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 32
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 33
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 34
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 35
# ✅ Data dikirim ke Kafka: table.public.tbl_promotions [0] dengan key: 36
# ✅ 36/36 data berhasil dikirim ke Kafka di topic 'table.public.tbl_promotions'!
# 🔄 Memproses: Topic='table.public.tbl_sales', File='df_sales.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 1
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 4
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 5
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 6
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 7
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 8
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 9
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 10
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 11
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 12
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 13
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 14
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 15
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 16
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 17
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 18
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 19
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 20
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 21
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 22
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 23
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 24
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 25
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 26
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 27
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 28
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 29
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 30
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 31
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 32
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 33
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 34
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 35
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 36
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 37
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 38
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 39
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 40
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 41
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 42
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 43
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 44
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 45
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 46
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 47
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 48
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 49
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 50
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 51
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 52
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 53
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 54
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 55
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 56
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 57
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 58
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 59
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 60
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 61
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 62
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 63
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 64
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 65
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 66
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 67
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 68
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 69
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 70
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 71
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 72
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 73
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 74
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 75
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 76
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 77
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 78
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 79
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 80
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 81
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 82
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 83
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 84
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 85
# ✅ Data dikirim ke Kafka: table.public.tbl_sales [0] dengan key: 86
# ...
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 74
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 75
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 76
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 77
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 78
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 79
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 80
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 81
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 82
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 83
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 84
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 85
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 86
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 87
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 88
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 89
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 90
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 91
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 92
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 93
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 94
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 95
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 96
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 97
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 98
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 99
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 100
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 101
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 102
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 103
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 104
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 105
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 106
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 107
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 108
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 109
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 110
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 111
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 112
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 113
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 114
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 115
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 116
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 117
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 118
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 119
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 120
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 121
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 122
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 123
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 124
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 125
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 126
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 127
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 128
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 129
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 130
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 131
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 132
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 133
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 134
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 135
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 136
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 137
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 138
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 139
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 140
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 141
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 142
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 143
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 144
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 145
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 146
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 147
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 148
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 149
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 150
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 151
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 152
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 153
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 154
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 155
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 156
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 157
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 158
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 159
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 160
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 161
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 162
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 163
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 164
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 165
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 166
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 167
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 168
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 169
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 170
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 171
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 172
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 173
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 174
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 175
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 176
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 177
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 178
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 179
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 180
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 181
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 182
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 183
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 184
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 185
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 186
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 187
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 188
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 189
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 190
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 191
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 192
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 193
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 194
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 195
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 196
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 197
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 198
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 199
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 200
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 201
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 202
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 203
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 204
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 205
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 206
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 207
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 208
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 209
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 210
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 211
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 212
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 213
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 214
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 215
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 216
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 217
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 218
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 219
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 220
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 221
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 222
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 223
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 224
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 225
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 226
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 227
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 228
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 229
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 230
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 231
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 232
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 233
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 234
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 235
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 236
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 237
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 238
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 239
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 240
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 241
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 242
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 243
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 244
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 245
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 246
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 247
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 248
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 249
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 250
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 251
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 252
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 253
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 254
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 255
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 256
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 257
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 258
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 259
# ✅ Data dikirim ke Kafka: table.public.tbl_schedulle_employee [0] dengan key: 260
# ✅ 260/260 data berhasil dikirim ke Kafka di topic 'table.public.tbl_schedulle_employee'!
# 🔄 Memproses: Topic='table.public.tbl_shipping_status', File='df_shipping_status.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_shipping_status [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_shipping_status [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_shipping_status [0] dengan key: 1
# ✅ 3/3 data berhasil dikirim ke Kafka di topic 'table.public.tbl_shipping_status'!
# 🔄 Memproses: Topic='table.public.tbl_payment_status', File='df_payment_status.csv'
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_status [0] dengan key: 3
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_status [0] dengan key: 2
# ✅ Data dikirim ke Kafka: table.public.tbl_payment_status [0] dengan key: 1
# ✅ 3/3 data berhasil dikirim ke Kafka di topic 'table.public.tbl_payment_status'!

# %%
import json 
import pandas as pd
from confluent_kafka import Producer

KAFKA_BROKER = "localhost:9092"
TOPIC_NAME = "tbl_customers"

Producer_conf = {'bootstrap.servers': KAFKA_BROKER}
Producer = Producer(Producer_conf)

df_cust = pd.read_csv("df_cust.csv")
cust_data = []

for _, row in df_cust.iterrows():
    

    payload = {
        "id": row["id"],
        "name": row["name"],
        "address": row["address"],
        "email": row["email"],
        "phone": row["phone"],
        "created_at": row["created_at"],
        "modified_at": row["modified_at"]
    }

    schema = {
        "schema": {  # Perbaikan dari "shema" ❌
            "fields": [
                {"type": "int32", "optional": False, "field": "id"},
                {"type": "string", "optional": False, "field": "name"},
                {"type": "string", "optional": False, "field": "address"},
                {"type": "string", "optional": False, "field": "email"},
                {"type": "string", "optional": False, "field": "phone"},
                {"type": "string", "optional": False, "field": "created_at"},
                {"type": "string", "optional": True, "field": "modified_at"}
            ],
            "optional": False,
            "name": "tbl_customers",
            "type": "struct"
        },
        "payload": payload
    }
    cust_data.append(schema)

def delivery_report(err, msg):
    if err is not None:
        print(f"❌ Gagal mengirim pesan: {err}")
    else:
        print(f"✅ Data dikirim ke Kafka: {msg.topic()} [{msg.partition()}]")

for record in cust_data:
    Producer.produce(TOPIC_NAME, json.dumps(record).encode("utf-8"), callback=delivery_report)

Producer.flush()
# Out:
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# ✅ Data dikirim ke Kafka: tbl_customers [0]
# 0

# %%
import json 
import pandas as pd
from confluent_kafka import Producer

KAFKA_BROKER = "localhost:9092"
TOPIC_NAME = "tbl_employee"

Producer_conf = {'bootstrap.servers': KAFKA_BROKER}
Producer = Producer(Producer_conf)

df_employee = pd.read_csv("df_employee.csv")
employee_data = []

for _, row in df_employee.iterrows():
    

    payload = {
        "id": row["id"],
        "branch_id": row["branch_id"],
        "name": row["name"],
        "salary": row["salary"],
        "active": row["active"],
        "address": row["address"],
        "email": row["email"],
        "created_at": row["created_at"]
    }

    schema = {
        "schema": {  # Perbaikan dari "shema" ❌
            "fields": [
                {"type": "int32", "optional": False, "field": "id"},
                {"type": "int32", "optional": False, "field": "branch_id"},
                {"type": "string", "optional": False, "field": "name"},
                {"type": "int32", "optional": False, "field": "salary"},
                {"type": "string", "optional": False, "field": "active"},
                {"type": "string", "optional": False, "field": "address"},
                {"type": "string", "optional": False, "field": "email"},
                {"type": "string", "optional": True, "field": "created_at"}
            ],
            "optional": False,
            "name": "tbl_employee",
            "type": "struct"
        },
        "payload": payload
    }
    employee_data.append(schema)

def delivery_report(err, msg):
    if err is not None:
        print(f"❌ Gagal mengirim pesan: {err}")
    else:
        print(f"✅ Data dikirim ke Kafka: {msg.topic()} [{msg.partition()}]")

for record in employee_data:
    Producer.produce(TOPIC_NAME, json.dumps(record).encode("utf-8"), callback=delivery_report)

Producer.flush()
# Out:
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# ✅ Data dikirim ke Kafka: tbl_employee [0]
# 0
